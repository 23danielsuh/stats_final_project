# %%
import numpy as np

# %%
print("Hello World!")
print('Hello World!')

# %%
x = 5
y = 'hi'
z = 5.5
b = True

# %%
if(x != 5 and x == 3):
    print("hi")
elif(x == 3):
    print("bye")
else:
    print("hello")

# %%
r = 25
t = 24
if(r == 25 or t == 24):
    print()

# %%
cnt = 0
x = 5
while(cnt < x):
    if(cnt == x - 1):
        print(cnt)
        break
    print(cnt, end = ' and ')
    cnt += 1

# %%
for i in range(0, 5):
    print(i)

# %%
x = [1, 2, 3, 4, 5]

for idx, value in enumerate(x):
    print(f'{idx} oaeuntaoeuhtnaoeu {value}')

# %%
d = {3: [1, 2, 3, 4, 5], 'b': [3, 5]}
print(d[3])
print(d['b'])

# %%
import seaborn as sns # for data visualzita
import pandas as pd # for spreadsheets

# %%
df = pd.DataFrame({'hi': np.random.rand(100), 'bye': np.random.rand(100)})
df.head()

# %%
sns.relplot(x = 'hi', y = 'bye', kind = 'line', data = df)
